# %%
import os
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split
from IPython.display import clear_output
from collections import defaultdict

# %%
base_folder = './'
processed_dataset = './DatasetPro'
index_file = 'sample_index.csv'
chord_distribution_file = os.path.join(processed_dataset, 'chord_distribution.csv')
split_index_file = os.path.join(processed_dataset, 'split_index.csv')
train_output_file = os.path.join(processed_dataset, 'train_features.csv')
val_output_file = os.path.join(processed_dataset, 'val_features.csv')
test_output_file = os.path.join(processed_dataset, 'test_features.csv')

# %%
# Load the chord distribution file
chord_distribution_df = pd.read_csv(chord_distribution_file)

# Calculate total chords by summing the percentages
total_chords = chord_distribution_df['Percentage'].sum()

# Find chords that appear less than 2% of the total chords
rare_chords = chord_distribution_df[chord_distribution_df["Percentage"] < (2 / total_chords) * 100]  # Less than 2%

# Display rare chords
print("🔍 Rare Chords (less than 2% occurrences):")
print(rare_chords)
# Out:
# 🔍 Rare Chords (less than 2% occurrences):
#      Chord  Percentage  Chord_Count
# 17   G:min    1.809031        74946
# 18   C:min    1.490460        61748
# 19  C#:min    1.404530        58188
# 20  F#:min    1.403467        58144
# 21   F:min    1.295885        53687
# 22     E:7    1.259630        52185
# 23  Eb:min    1.254296        51964
# 24     G:7    1.183838        49045
# 25     A:7    1.147245        47529
# 26     D:7    1.138459        47165
# 27     C:7    1.114007        46152
# 28     F:7    1.047097        43380
# 29    Ab:7    0.982867        40719
# 30    Eb:7    0.921677        38184
# 31  Bb:min    0.777937        32229
# 32     B:7    0.754282        31249
# 33  Ab:min    0.667651        27660
# 34    Bb:7    0.558621        23143
# 35    C#:7    0.527942        21872
# 36    F#:7    0.510080        21132
# 37     NaN    0.011007          456

# %%
# Convert all values to strings and then sort
all_chords = sorted(chord_distribution_df['Chord'].dropna().astype(str).unique())
print(all_chords)
# Out:
# ['A:7', 'A:maj', 'A:min', 'Ab:7', 'Ab:maj', 'Ab:min', 'B:7', 'B:maj', 'B:min', 'Bb:7', 'Bb:maj', 'Bb:min', 'C#:7', 'C#:maj', 'C#:min', 'C:7', 'C:maj', 'C:min', 'D:7', 'D:maj', 'D:min', 'E:7', 'E:maj', 'E:min', 'Eb:7', 'Eb:maj', 'Eb:min', 'F#:7', 'F#:maj', 'F#:min', 'F:7', 'F:maj', 'F:min', 'G:7', 'G:maj', 'G:min', 'N']

# %%
# Load the chord distribution file
chord_distribution_df = pd.read_csv(chord_distribution_file)

# Load sample index file (contains all sample IDs)
index_df = pd.read_csv(index_file)

# Define split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Threshold for rare chords
rare_threshold = (1 / chord_distribution_df['Percentage'].sum()) * 100

# Identify rare chords
rare_chords = chord_distribution_df[chord_distribution_df["Percentage"] < rare_threshold]['Chord'].tolist()

print(f"🔍 Identified {len(rare_chords)} rare chords :")
print(rare_chords)

# Step 1: Map Chords to Songs
chord_to_songs = defaultdict(set)
song_to_chords = {}

for sample_id in index_df['sample_id'].astype(str).str.zfill(4):  # Ensure correct formatting
    sample_folder = os.path.join(processed_dataset, sample_id)
    merged_file = os.path.join(sample_folder, 'merged_chroma_lab.csv')

    if os.path.exists(merged_file):
        df = pd.read_csv(merged_file)
        unique_chords = set(df['Final_Chord'].dropna().unique())

        # Store song → chords mapping
        song_to_chords[sample_id] = unique_chords

        # Store chord → songs mapping
        for chord in unique_chords:
            chord_to_songs[chord].add(sample_id)

print(f"🎵 Total songs processed: {len(song_to_chords)}")
print(f"🎸 Sample song with its chords: {list(song_to_chords.items())[0]}")
# Out:
# 🔍 Identified 9 rare chords :
# ['Ab:7', 'Eb:7', 'Bb:min', 'B:7', 'Ab:min', 'Bb:7', 'C#:7', 'F#:7', nan]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 30
#      27 merged_file = os.path.join(sample_folder, 'merged_chroma_lab.csv')
#      29 if os.path.exists(merged_file):
# ---> 30     df = pd.read_csv(merged_file)
#      31     unique_chords = set(df['Final_Chord'].dropna().unique())
#      33     # Store song → chords mapping
#
# File /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /usr/local/lib/python3.11/dist-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
# Step 2: Balanced Song Selection
train_songs = set()
val_songs = set()
test_songs = set()

# Start with rare chord songs (so they are included in all splits)
rare_songs = {song for chord in rare_chords for song in chord_to_songs[chord]}

print(f"🎯 {len(rare_songs)} songs contain rare chords.")

# Assign rare chord songs first
for song in rare_songs:
    if len(train_songs) / len(index_df) < train_ratio:
        train_songs.add(song)
    elif len(val_songs) / len(index_df) < val_ratio:
        val_songs.add(song)
    else:
        test_songs.add(song)

print(f"✅ After rare chord assignment - Train: {len(train_songs)}, Val: {len(val_songs)}, Test: {len(test_songs)}")

# Assign remaining songs while balancing chord distributions
remaining_songs = list(set(song_to_chords.keys()) - rare_songs)
np.random.shuffle(remaining_songs)

for song in remaining_songs:
    if len(train_songs) / len(index_df) < train_ratio:
        train_songs.add(song)
    elif len(val_songs) / len(index_df) < val_ratio:
        val_songs.add(song)
    else:
        test_songs.add(song)

print(f"🎯 Final Split Counts - Train: {len(train_songs)}, Val: {len(val_songs)}, Test: {len(test_songs)}")
# Out:
# 🎯 361 songs contain rare chords.
# ✅ After rare chord assignment - Train: 361, Val: 0, Test: 0
# 🎯 Final Split Counts - Train: 623, Val: 134, Test: 133

# %%
# Step 3: Save Index File with Splits
index_df['split'] = index_df['sample_id'].astype(str).str.zfill(4).apply(
    lambda x: 'train' if x in train_songs else ('val' if x in val_songs else 'test')
)

split_index_file = os.path.join(processed_dataset, 'split_index.csv')
index_df.to_csv(split_index_file, index=False)

print("🚀 Song-based stratified dataset split **completed** successfully!")
print(f"📁 Split details saved in {split_index_file}")
# Out:
# 🚀 Song-based stratified dataset split **completed** successfully!
# 📁 Split details saved in ./DatasetPro/split_index.csv

# %%
import numpy as np
import os
import pandas as pd

# Initialize lists to store the features, labels, and sequence indices
X_train, y_train, sequence_indices_train = [], [], []
X_val, y_val, sequence_indices_val = [], [], []
X_test, y_test, sequence_indices_test = [], [], []

# Initialize sequence ID trackers
sequence_id_train = 0
sequence_id_val = 0
sequence_id_test = 0

# Iterate through the split_index and process the files accordingly
for idx, row in split_index_df.iterrows():
    sample_id = str(row['sample_id']).zfill(4)
    split = row['split']  # 'train', 'val', or 'test'
    
    if split not in ['train', 'val', 'test']:
        continue  # Skip invalid splits
    
    print(f"🔍 Processing sample {sample_id} for split: {split}...")

    sample_folder = os.path.join(processed_dataset, sample_id)
    merged_file = os.path.join(sample_folder, 'merged_chroma_lab.csv')

    if os.path.exists(merged_file):
        df = pd.read_csv(merged_file)
        
        # Extract the normal chroma (columns 14 to 25)
        normal_chroma = df.iloc[:, 13:25].values  # Shape: (timesteps, 12)
        
        # Labels (Final_Chord)
        labels = df['Final_Chord'].values
        
        # Filter out NaN labels
        valid_idx = ~pd.isna(labels)
        normal_chroma = normal_chroma[valid_idx]
        labels = labels[valid_idx]
        
        # Map labels to numeric values
        chord_mapping = {chord: idx for idx, chord in enumerate(all_chords)}
        labels_numeric = np.array([chord_mapping[chord] for chord in labels])
        
        # Store the sequence and track index boundaries based on split
        if split == 'train':
            X_train.append(normal_chroma)
            y_train.append(labels_numeric)
            sequence_indices_train.extend([sequence_id_train] * len(normal_chroma))  # Extend with sequence ID
            sequence_id_train += 1  # Increment sequence ID for next sequence
        elif split == 'val':
            X_val.append(normal_chroma)
            y_val.append(labels_numeric)
            sequence_indices_val.extend([sequence_id_val] * len(normal_chroma))  # Extend with sequence ID
            sequence_id_val += 1  # Increment sequence ID for next sequence
        elif split == 'test':
            X_test.append(normal_chroma)
            y_test.append(labels_numeric)
            sequence_indices_test.extend([sequence_id_test] * len(normal_chroma))  # Extend with sequence ID
            sequence_id_test += 1  # Increment sequence ID for next sequence

    print(f"✅ Finished processing sample {sample_id}.")

# Flatten the feature arrays and labels
X_train = np.concatenate(X_train, axis=0)
y_train = np.concatenate(y_train, axis=0)

X_val = np.concatenate(X_val, axis=0)
y_val = np.concatenate(y_val, axis=0)

X_test = np.concatenate(X_test, axis=0)
y_test = np.concatenate(y_test, axis=0)

# Convert sequence indices to numpy arrays (sequence indices should now match the lengths of X and y)
sequence_indices_train = np.array(sequence_indices_train)
sequence_indices_val = np.array(sequence_indices_val)
sequence_indices_test = np.array(sequence_indices_test)

# Save the data with proper headers
chroma_headers = df.columns[13:25].tolist()  # Chroma feature names
headers = ','.join(chroma_headers + ['label', 'sequence_id'])  # Updated header

# Stack the arrays and save them to CSV
np.savetxt(train_output_file, np.column_stack((X_train, y_train, sequence_indices_train)), delimiter=',', header=headers, comments='')
np.savetxt(val_output_file, np.column_stack((X_val, y_val, sequence_indices_val)), delimiter=',', header=headers, comments='')
np.savetxt(test_output_file, np.column_stack((X_test, y_test, sequence_indices_test)), delimiter=',', header=headers, comments='')

print(f"🎯 Dataset processing complete!")
print(f"📁 Train data saved in: {train_output_file}")
print(f"📁 Validation data saved in: {val_output_file}")
print(f"📁 Test data saved in: {test_output_file}")
# Out:
# 🔍 Processing sample 0003 for split: train...
# ✅ Finished processing sample 0003.
# 🔍 Processing sample 0004 for split: train...
# ✅ Finished processing sample 0004.
# 🔍 Processing sample 0006 for split: test...
# ✅ Finished processing sample 0006.
# 🔍 Processing sample 0010 for split: train...
# ✅ Finished processing sample 0010.
# 🔍 Processing sample 0012 for split: val...
# ✅ Finished processing sample 0012.
# 🔍 Processing sample 0015 for split: train...
# ✅ Finished processing sample 0015.
# 🔍 Processing sample 0016 for split: train...
# ✅ Finished processing sample 0016.
# 🔍 Processing sample 0018 for split: train...
# ✅ Finished processing sample 0018.
# 🔍 Processing sample 0019 for split: train...
# ✅ Finished processing sample 0019.
# 🔍 Processing sample 0021 for split: train...
# ✅ Finished processing sample 0021.
# 🔍 Processing sample 0022 for split: train...
# ✅ Finished processing sample 0022.
# 🔍 Processing sample 0023 for split: train...
# ✅ Finished processing sample 0023.
# 🔍 Processing sample 0025 for split: test...
# ✅ Finished processing sample 0025.
# 🔍 Processing sample 0026 for split: train...
# ✅ Finished processing sample 0026.
# 🔍 Processing sample 0027 for split: train...
# ✅ Finished processing sample 0027.
# 🔍 Processing sample 0029 for split: train...
# ✅ Finished processing sample 0029.
# 🔍 Processing sample 0030 for split: train...
# ✅ Finished processing sample 0030.
# 🔍 Processing sample 0033 for split: test...
# ✅ Finished processing sample 0033.
# 🔍 Processing sample 0034 for split: val...
# ✅ Finished processing sample 0034.
# 🔍 Processing sample 0035 for split: train...
# ✅ Finished processing sample 0035.
# 🔍 Processing sample 0037 for split: train...
# ✅ Finished processing sample 0037.
# 🔍 Processing sample 0039 for split: train...
# ✅ Finished processing sample 0039.
# 🔍 Processing sample 0040 for split: train...
# ✅ Finished processing sample 0040.
# 🔍 Processing sample 0041 for split: train...
# ✅ Finished processing sample 0041.
# 🔍 Processing sample 0043 for split: train...
# ✅ Finished processing sample 0043.
# 🔍 Processing sample 0044 for split: train...
# ✅ Finished processing sample 0044.
# 🔍 Processing sample 0046 for split: val...
# ✅ Finished processing sample 0046.
# 🔍 Processing sample 0049 for split: train...
# ✅ Finished processing sample 0049.
# 🔍 Processing sample 0050 for split: val...
# ✅ Finished processing sample 0050.
# 🔍 Processing sample 0051 for split: train...
# ✅ Finished processing sample 0051.
# 🔍 Processing sample 0053 for split: train...
# ✅ Finished processing sample 0053.
# 🔍 Processing sample 0054 for split: train...
# ✅ Finished processing sample 0054.
# 🔍 Processing sample 0055 for split: val...
# ✅ Finished processing sample 0055.
# 🔍 Processing sample 0056 for split: train...
# ✅ Finished processing sample 0056.
# 🔍 Processing sample 0059 for split: test...
# ✅ Finished processing sample 0059.
# 🔍 Processing sample 0061 for split: train...
# ✅ Finished processing sample 0061.
# 🔍 Processing sample 0062 for split: train...
# ✅ Finished processing sample 0062.
# 🔍 Processing sample 0064 for split: train...
# ✅ Finished processing sample 0064.
# 🔍 Processing sample 0066 for split: train...
# ✅ Finished processing sample 0066.
# 🔍 Processing sample 0067 for split: train...
# ✅ Finished processing sample 0067.
# 🔍 Processing sample 0068 for split: train...
# ✅ Finished processing sample 0068.
# 🔍 Processing sample 0070 for split: train...
# ✅ Finished processing sample 0070.
# 🔍 Processing sample 0071 for split: val...
# ✅ Finished processing sample 0071.
# 🔍 Processing sample 0072 for split: train...
# ✅ Finished processing sample 0072.
# 🔍 Processing sample 0073 for split: train...
# ✅ Finished processing sample 0073.
# 🔍 Processing sample 0074 for split: train...
# ✅ Finished processing sample 0074.
# 🔍 Processing sample 0075 for split: train...
# ✅ Finished processing sample 0075.
# 🔍 Processing sample 0077 for split: train...
# ✅ Finished processing sample 0077.
# 🔍 Processing sample 0078 for split: train...
# ✅ Finished processing sample 0078.
# 🔍 Processing sample 0079 for split: train...
# ✅ Finished processing sample 0079.
# 🔍 Processing sample 0081 for split: test...
# ✅ Finished processing sample 0081.
# 🔍 Processing sample 0083 for split: test...
# ✅ Finished processing sample 0083.
# 🔍 Processing sample 0085 for split: train...
# ✅ Finished processing sample 0085.
# 🔍 Processing sample 0086 for split: train...
# ✅ Finished processing sample 0086.
# 🔍 Processing sample 0088 for split: val...
# ✅ Finished processing sample 0088.
# 🔍 Processing sample 0089 for split: val...
# ✅ Finished processing sample 0089.
# 🔍 Processing sample 0091 for split: train...
# ✅ Finished processing sample 0091.
# 🔍 Processing sample 0092 for split: train...
# ✅ Finished processing sample 0092.
# 🔍 Processing sample 0094 for split: train...
# ✅ Finished processing sample 0094.
# 🔍 Processing sample 0095 for split: val...
# ✅ Finished processing sample 0095.
# 🔍 Processing sample 0097 for split: train...
# ✅ Finished processing sample 0097.
# 🔍 Processing sample 0099 for split: train...
# ✅ Finished processing sample 0099.
# 🔍 Processing sample 0100 for split: val...
# ✅ Finished processing sample 0100.
# 🔍 Processing sample 0101 for split: train...
# ✅ Finished processing sample 0101.
# 🔍 Processing sample 0102 for split: train...
# ✅ Finished processing sample 0102.
# 🔍 Processing sample 0104 for split: val...
# ✅ Finished processing sample 0104.
# 🔍 Processing sample 0105 for split: train...
# ✅ Finished processing sample 0105.
# 🔍 Processing sample 0106 for split: train...
# ✅ Finished processing sample 0106.
# 🔍 Processing sample 0107 for split: train...
# ✅ Finished processing sample 0107.
# 🔍 Processing sample 0109 for split: train...
# ✅ Finished processing sample 0109.
# 🔍 Processing sample 0111 for split: train...
# ✅ Finished processing sample 0111.
# 🔍 Processing sample 0112 for split: train...
# ✅ Finished processing sample 0112.
# 🔍 Processing sample 0114 for split: train...
# ✅ Finished processing sample 0114.
# 🔍 Processing sample 0115 for split: train...
# ✅ Finished processing sample 0115.
# 🔍 Processing sample 0116 for split: val...
# ✅ Finished processing sample 0116.
# 🔍 Processing sample 0119 for split: val...
# ✅ Finished processing sample 0119.
# 🔍 Processing sample 0120 for split: train...
# ✅ Finished processing sample 0120.
# 🔍 Processing sample 0122 for split: train...
# ✅ Finished processing sample 0122.
# 🔍 Processing sample 0123 for split: train...
# ✅ Finished processing sample 0123.
# 🔍 Processing sample 0124 for split: train...
# ✅ Finished processing sample 0124.
# 🔍 Processing sample 0126 for split: train...
# ✅ Finished processing sample 0126.
# 🔍 Processing sample 0127 for split: train...
# ✅ Finished processing sample 0127.
# 🔍 Processing sample 0128 for split: train...
# ✅ Finished processing sample 0128.
# 🔍 Processing sample 0130 for split: test...
# ✅ Finished processing sample 0130.
# 🔍 Processing sample 0131 for split: train...
# ✅ Finished processing sample 0131.
# 🔍 Processing sample 0133 for split: test...
# ✅ Finished processing sample 0133.
# 🔍 Processing sample 0134 for split: train...
# ✅ Finished processing sample 0134.
# 🔍 Processing sample 0139 for split: train...
# ✅ Finished processing sample 0139.
# 🔍 Processing sample 0140 for split: train...
# ✅ Finished processing sample 0140.
# 🔍 Processing sample 0141 for split: train...
# ✅ Finished processing sample 0141.
# 🔍 Processing sample 0145 for split: train...
# ✅ Finished processing sample 0145.
# 🔍 Processing sample 0147 for split: test...
# ✅ Finished processing sample 0147.
# 🔍 Processing sample 0148 for split: test...
# ✅ Finished processing sample 0148.
# 🔍 Processing sample 0149 for split: val...
# ✅ Finished processing sample 0149.
# 🔍 Processing sample 0150 for split: train...
# ✅ Finished processing sample 0150.
# 🔍 Processing sample 0153 for split: train...
# ✅ Finished processing sample 0153.
# 🔍 Processing sample 0154 for split: train...
# ✅ Finished processing sample 0154.
# 🔍 Processing sample 0155 for split: val...
# ✅ Finished processing sample 0155.
# 🔍 Processing sample 0157 for split: train...
# ✅ Finished processing sample 0157.
# 🔍 Processing sample 0158 for split: test...
# ✅ Finished processing sample 0158.
# 🔍 Processing sample 0159 for split: test...
# ✅ Finished processing sample 0159.
# 🔍 Processing sample 0160 for split: val...
# ✅ Finished processing sample 0160.
# 🔍 Processing sample 0162 for split: train...
# ✅ Finished processing sample 0162.
# 🔍 Processing sample 0167 for split: test...
# ✅ Finished processing sample 0167.
# 🔍 Processing sample 0168 for split: val...
# ✅ Finished processing sample 0168.
# 🔍 Processing sample 0169 for split: train...
# ✅ Finished processing sample 0169.
# 🔍 Processing sample 0170 for split: train...
# ✅ Finished processing sample 0170.
# 🔍 Processing sample 0172 for split: test...
# ✅ Finished processing sample 0172.
# 🔍 Processing sample 0176 for split: train...
# ✅ Finished processing sample 0176.
# 🔍 Processing sample 0177 for split: train...
# ✅ Finished processing sample 0177.
# 🔍 Processing sample 0179 for split: train...
# ✅ Finished processing sample 0179.
# 🔍 Processing sample 0180 for split: val...
# ✅ Finished processing sample 0180.
# 🔍 Processing sample 0181 for split: val...
# ✅ Finished processing sample 0181.
# 🔍 Processing sample 0182 for split: train...
# ✅ Finished processing sample 0182.
# 🔍 Processing sample 0183 for split: val...
# ✅ Finished processing sample 0183.
# 🔍 Processing sample 0184 for split: train...
# ✅ Finished processing sample 0184.
# 🔍 Processing sample 0185 for split: val...
# ✅ Finished processing sample 0185.
# 🔍 Processing sample 0187 for split: train...
# ✅ Finished processing sample 0187.
# 🔍 Processing sample 0188 for split: train...
# ✅ Finished processing sample 0188.
# 🔍 Processing sample 0190 for split: test...
# ✅ Finished processing sample 0190.
# 🔍 Processing sample 0191 for split: val...
# ✅ Finished processing sample 0191.
# 🔍 Processing sample 0192 for split: train...
# ✅ Finished processing sample 0192.
# 🔍 Processing sample 0193 for split: train...
# ✅ Finished processing sample 0193.
# 🔍 Processing sample 0194 for split: train...
# ✅ Finished processing sample 0194.
# 🔍 Processing sample 0195 for split: train...
# ✅ Finished processing sample 0195.
# 🔍 Processing sample 0196 for split: train...
# ✅ Finished processing sample 0196.
# 🔍 Processing sample 0198 for split: test...
# ✅ Finished processing sample 0198.
# 🔍 Processing sample 0199 for split: train...
# ✅ Finished processing sample 0199.
# 🔍 Processing sample 0202 for split: val...
# ✅ Finished processing sample 0202.
# 🔍 Processing sample 0203 for split: train...
# ✅ Finished processing sample 0203.
# 🔍 Processing sample 0204 for split: train...
# ✅ Finished processing sample 0204.
# 🔍 Processing sample 0205 for split: test...
# ✅ Finished processing sample 0205.
# 🔍 Processing sample 0206 for split: train...
# ✅ Finished processing sample 0206.
# 🔍 Processing sample 0207 for split: val...
# ✅ Finished processing sample 0207.
# 🔍 Processing sample 0208 for split: train...
# ✅ Finished processing sample 0208.
# 🔍 Processing sample 0209 for split: train...
# ✅ Finished processing sample 0209.
# 🔍 Processing sample 0210 for split: train...
# ✅ Finished processing sample 0210.
# 🔍 Processing sample 0212 for split: val...
# ✅ Finished processing sample 0212.
# 🔍 Processing sample 0213 for split: train...
# ✅ Finished processing sample 0213.
# 🔍 Processing sample 0214 for split: train...
# ✅ Finished processing sample 0214.
# 🔍 Processing sample 0215 for split: train...
# ✅ Finished processing sample 0215.
# 🔍 Processing sample 0216 for split: train...
# ✅ Finished processing sample 0216.
# 🔍 Processing sample 0217 for split: train...
# ✅ Finished processing sample 0217.
# 🔍 Processing sample 0218 for split: train...
# ✅ Finished processing sample 0218.
# 🔍 Processing sample 0220 for split: train...
# ✅ Finished processing sample 0220.
# 🔍 Processing sample 0221 for split: train...
# ✅ Finished processing sample 0221.
# 🔍 Processing sample 0222 for split: train...
# ✅ Finished processing sample 0222.
# 🔍 Processing sample 0223 for split: test...
# ✅ Finished processing sample 0223.
# 🔍 Processing sample 0224 for split: train...
# ✅ Finished processing sample 0224.
# 🔍 Processing sample 0227 for split: test...
# ✅ Finished processing sample 0227.
# 🔍 Processing sample 0228 for split: train...
# ✅ Finished processing sample 0228.
# 🔍 Processing sample 0229 for split: test...
# ✅ Finished processing sample 0229.
# 🔍 Processing sample 0231 for split: train...
# ✅ Finished processing sample 0231.
# 🔍 Processing sample 0234 for split: val...
# ✅ Finished processing sample 0234.
# 🔍 Processing sample 0235 for split: train...
# ✅ Finished processing sample 0235.
# 🔍 Processing sample 0236 for split: train...
# ✅ Finished processing sample 0236.
# 🔍 Processing sample 0238 for split: train...
# ✅ Finished processing sample 0238.
# 🔍 Processing sample 0239 for split: train...
# ✅ Finished processing sample 0239.
# 🔍 Processing sample 0240 for split: val...
# ✅ Finished processing sample 0240.
# 🔍 Processing sample 0241 for split: train...
# ✅ Finished processing sample 0241.
# 🔍 Processing sample 0242 for split: train...
# ✅ Finished processing sample 0242.
# 🔍 Processing sample 0244 for split: val...
# ✅ Finished processing sample 0244.
# 🔍 Processing sample 0245 for split: val...
# ✅ Finished processing sample 0245.
# 🔍 Processing sample 0246 for split: val...
# ✅ Finished processing sample 0246.
# 🔍 Processing sample 0247 for split: val...
# ✅ Finished processing sample 0247.
# 🔍 Processing sample 0248 for split: train...
# ✅ Finished processing sample 0248.
# 🔍 Processing sample 0249 for split: train...
# ✅ Finished processing sample 0249.
# 🔍 Processing sample 0250 for split: train...
# ✅ Finished processing sample 0250.
# 🔍 Processing sample 0251 for split: train...
# ✅ Finished processing sample 0251.
# 🔍 Processing sample 0253 for split: train...
# ✅ Finished processing sample 0253.
# 🔍 Processing sample 0254 for split: train...
# ✅ Finished processing sample 0254.
# 🔍 Processing sample 0256 for split: train...
# ✅ Finished processing sample 0256.
# 🔍 Processing sample 0257 for split: test...
# ✅ Finished processing sample 0257.
# 🔍 Processing sample 0258 for split: train...
# ✅ Finished processing sample 0258.
# 🔍 Processing sample 0259 for split: train...
# ✅ Finished processing sample 0259.
# 🔍 Processing sample 0260 for split: train...
# ✅ Finished processing sample 0260.
# 🔍 Processing sample 0261 for split: train...
# ✅ Finished processing sample 0261.
# 🔍 Processing sample 0263 for split: val...
# ✅ Finished processing sample 0263.
# 🔍 Processing sample 0264 for split: train...
# ✅ Finished processing sample 0264.
# 🔍 Processing sample 0265 for split: train...
# ✅ Finished processing sample 0265.
# 🔍 Processing sample 0267 for split: train...
# ✅ Finished processing sample 0267.
# 🔍 Processing sample 0268 for split: train...
# ✅ Finished processing sample 0268.
# 🔍 Processing sample 0269 for split: test...
# ✅ Finished processing sample 0269.
# 🔍 Processing sample 0270 for split: train...
# ✅ Finished processing sample 0270.
# 🔍 Processing sample 0271 for split: val...
# ✅ Finished processing sample 0271.
# 🔍 Processing sample 0275 for split: train...
# ✅ Finished processing sample 0275.
# 🔍 Processing sample 0276 for split: train...
# ✅ Finished processing sample 0276.
# 🔍 Processing sample 0278 for split: train...
# ✅ Finished processing sample 0278.
# 🔍 Processing sample 0279 for split: train...
# ✅ Finished processing sample 0279.
# 🔍 Processing sample 0280 for split: train...
# ✅ Finished processing sample 0280.
# 🔍 Processing sample 0281 for split: test...
# ✅ Finished processing sample 0281.
# 🔍 Processing sample 0282 for split: train...
# ✅ Finished processing sample 0282.
# 🔍 Processing sample 0284 for split: train...
# ✅ Finished processing sample 0284.
# 🔍 Processing sample 0288 for split: train...
# ✅ Finished processing sample 0288.
# 🔍 Processing sample 0289 for split: train...
# ✅ Finished processing sample 0289.
# 🔍 Processing sample 0290 for split: train...
# ✅ Finished processing sample 0290.
# 🔍 Processing sample 0291 for split: train...
# ✅ Finished processing sample 0291.
# 🔍 Processing sample 0292 for split: train...
# ✅ Finished processing sample 0292.
# 🔍 Processing sample 0293 for split: train...
# ✅ Finished processing sample 0293.
# 🔍 Processing sample 0294 for split: train...
# ✅ Finished processing sample 0294.
# 🔍 Processing sample 0295 for split: train...
# ✅ Finished processing sample 0295.
# 🔍 Processing sample 0296 for split: test...
# ✅ Finished processing sample 0296.
# 🔍 Processing sample 0297 for split: train...
# ✅ Finished processing sample 0297.
# 🔍 Processing sample 0300 for split: test...
# ✅ Finished processing sample 0300.
# 🔍 Processing sample 0302 for split: train...
# ✅ Finished processing sample 0302.
# 🔍 Processing sample 0303 for split: train...
# ✅ Finished processing sample 0303.
# 🔍 Processing sample 0304 for split: train...
# ✅ Finished processing sample 0304.
# 🔍 Processing sample 0306 for split: train...
# ✅ Finished processing sample 0306.
# 🔍 Processing sample 0307 for split: train...
# ✅ Finished processing sample 0307.
# 🔍 Processing sample 0308 for split: train...
# ✅ Finished processing sample 0308.
# 🔍 Processing sample 0309 for split: train...
# ✅ Finished processing sample 0309.
# 🔍 Processing sample 0310 for split: train...
# ✅ Finished processing sample 0310.
# 🔍 Processing sample 0312 for split: val...
# ✅ Finished processing sample 0312.
# 🔍 Processing sample 0314 for split: train...
# ✅ Finished processing sample 0314.
# 🔍 Processing sample 0315 for split: test...
# ✅ Finished processing sample 0315.
# 🔍 Processing sample 0317 for split: train...
# ✅ Finished processing sample 0317.
# 🔍 Processing sample 0318 for split: train...
# ✅ Finished processing sample 0318.
# 🔍 Processing sample 0319 for split: train...
# ✅ Finished processing sample 0319.
# 🔍 Processing sample 0320 for split: val...
# ✅ Finished processing sample 0320.
# 🔍 Processing sample 0322 for split: train...
# ✅ Finished processing sample 0322.
# 🔍 Processing sample 0323 for split: train...
# ✅ Finished processing sample 0323.
# 🔍 Processing sample 0324 for split: val...
# ✅ Finished processing sample 0324.
# 🔍 Processing sample 0325 for split: train...
# ✅ Finished processing sample 0325.
# 🔍 Processing sample 0326 for split: train...
# ✅ Finished processing sample 0326.
# 🔍 Processing sample 0329 for split: train...
# ✅ Finished processing sample 0329.
# 🔍 Processing sample 0330 for split: train...
# ✅ Finished processing sample 0330.
# 🔍 Processing sample 0331 for split: train...
# ✅ Finished processing sample 0331.
# 🔍 Processing sample 0332 for split: train...
# ✅ Finished processing sample 0332.
# 🔍 Processing sample 0334 for split: train...
# ✅ Finished processing sample 0334.
# 🔍 Processing sample 0335 for split: train...
# ✅ Finished processing sample 0335.
# 🔍 Processing sample 0336 for split: train...
# ✅ Finished processing sample 0336.
# 🔍 Processing sample 0338 for split: train...
# ✅ Finished processing sample 0338.
# 🔍 Processing sample 0339 for split: train...
# ✅ Finished processing sample 0339.
# 🔍 Processing sample 0341 for split: train...
# ✅ Finished processing sample 0341.
# 🔍 Processing sample 0343 for split: train...
# ✅ Finished processing sample 0343.
# 🔍 Processing sample 0345 for split: train...
# ✅ Finished processing sample 0345.
# 🔍 Processing sample 0346 for split: test...
# ✅ Finished processing sample 0346.
# 🔍 Processing sample 0347 for split: val...
# ✅ Finished processing sample 0347.
# 🔍 Processing sample 0348 for split: val...
# ✅ Finished processing sample 0348.
# 🔍 Processing sample 0349 for split: train...
# ✅ Finished processing sample 0349.
# 🔍 Processing sample 0351 for split: train...
# ✅ Finished processing sample 0351.
# 🔍 Processing sample 0352 for split: train...
# ✅ Finished processing sample 0352.
# 🔍 Processing sample 0353 for split: val...
# ✅ Finished processing sample 0353.
# 🔍 Processing sample 0354 for split: train...
# ✅ Finished processing sample 0354.
# 🔍 Processing sample 0355 for split: train...
# ✅ Finished processing sample 0355.
# 🔍 Processing sample 0356 for split: train...
# ✅ Finished processing sample 0356.
# 🔍 Processing sample 0358 for split: train...
# ✅ Finished processing sample 0358.
# 🔍 Processing sample 0359 for split: train...
# ✅ Finished processing sample 0359.
# 🔍 Processing sample 0360 for split: train...
# ✅ Finished processing sample 0360.
# 🔍 Processing sample 0361 for split: train...
# ✅ Finished processing sample 0361.
# 🔍 Processing sample 0362 for split: val...
# ✅ Finished processing sample 0362.
# 🔍 Processing sample 0364 for split: test...
# ✅ Finished processing sample 0364.
# 🔍 Processing sample 0366 for split: train...
# ✅ Finished processing sample 0366.
# 🔍 Processing sample 0367 for split: train...
# ✅ Finished processing sample 0367.
# 🔍 Processing sample 0369 for split: train...
# ✅ Finished processing sample 0369.
# 🔍 Processing sample 0370 for split: train...
# ✅ Finished processing sample 0370.
# 🔍 Processing sample 0371 for split: train...
# ✅ Finished processing sample 0371.
# 🔍 Processing sample 0372 for split: test...
# ✅ Finished processing sample 0372.
# 🔍 Processing sample 0377 for split: train...
# ✅ Finished processing sample 0377.
# 🔍 Processing sample 0378 for split: test...
# ✅ Finished processing sample 0378.
# 🔍 Processing sample 0380 for split: train...
# ✅ Finished processing sample 0380.
# 🔍 Processing sample 0381 for split: val...
# ✅ Finished processing sample 0381.
# 🔍 Processing sample 0382 for split: train...
# ✅ Finished processing sample 0382.
# 🔍 Processing sample 0383 for split: train...
# ✅ Finished processing sample 0383.
# 🔍 Processing sample 0384 for split: test...
# ✅ Finished processing sample 0384.
# 🔍 Processing sample 0385 for split: train...
# ✅ Finished processing sample 0385.
# 🔍 Processing sample 0386 for split: val...
# ✅ Finished processing sample 0386.
# 🔍 Processing sample 0387 for split: train...
# ✅ Finished processing sample 0387.
# 🔍 Processing sample 0389 for split: train...
# ✅ Finished processing sample 0389.
# 🔍 Processing sample 0390 for split: test...
# ✅ Finished processing sample 0390.
# 🔍 Processing sample 0391 for split: train...
# ✅ Finished processing sample 0391.
# 🔍 Processing sample 0393 for split: test...
# ✅ Finished processing sample 0393.
# 🔍 Processing sample 0395 for split: val...
# ✅ Finished processing sample 0395.
# 🔍 Processing sample 0396 for split: train...
# ✅ Finished processing sample 0396.
# 🔍 Processing sample 0397 for split: test...
# ✅ Finished processing sample 0397.
# 🔍 Processing sample 0399 for split: train...
# ✅ Finished processing sample 0399.
# 🔍 Processing sample 0400 for split: train...
# ✅ Finished processing sample 0400.
# 🔍 Processing sample 0401 for split: train...
# ✅ Finished processing sample 0401.
# 🔍 Processing sample 0402 for split: test...
# ✅ Finished processing sample 0402.
# 🔍 Processing sample 0403 for split: test...
# ✅ Finished processing sample 0403.
# 🔍 Processing sample 0404 for split: train...
# ✅ Finished processing sample 0404.
# 🔍 Processing sample 0406 for split: val...
# ✅ Finished processing sample 0406.
# 🔍 Processing sample 0407 for split: val...
# ✅ Finished processing sample 0407.
# 🔍 Processing sample 0410 for split: train...
# ✅ Finished processing sample 0410.
# 🔍 Processing sample 0412 for split: train...
# ✅ Finished processing sample 0412.
# 🔍 Processing sample 0414 for split: train...
# ✅ Finished processing sample 0414.
# 🔍 Processing sample 0415 for split: val...
# ✅ Finished processing sample 0415.
# 🔍 Processing sample 0417 for split: train...
# ✅ Finished processing sample 0417.
# 🔍 Processing sample 0418 for split: test...
# ✅ Finished processing sample 0418.
# 🔍 Processing sample 0419 for split: train...
# ✅ Finished processing sample 0419.
# 🔍 Processing sample 0421 for split: train...
# ✅ Finished processing sample 0421.
# 🔍 Processing sample 0425 for split: train...
# ✅ Finished processing sample 0425.
# 🔍 Processing sample 0426 for split: val...
# ✅ Finished processing sample 0426.
# 🔍 Processing sample 0427 for split: train...
# ✅ Finished processing sample 0427.
# 🔍 Processing sample 0429 for split: val...
# ✅ Finished processing sample 0429.
# 🔍 Processing sample 0430 for split: train...
# ✅ Finished processing sample 0430.
# 🔍 Processing sample 0432 for split: train...
# ✅ Finished processing sample 0432.
# 🔍 Processing sample 0433 for split: test...
# ✅ Finished processing sample 0433.
# 🔍 Processing sample 0434 for split: train...
# ✅ Finished processing sample 0434.
# 🔍 Processing sample 0439 for split: train...
# ✅ Finished processing sample 0439.
# 🔍 Processing sample 0442 for split: train...
# ✅ Finished processing sample 0442.
# 🔍 Processing sample 0443 for split: train...
# ✅ Finished processing sample 0443.
# 🔍 Processing sample 0444 for split: val...
# ✅ Finished processing sample 0444.
# 🔍 Processing sample 0445 for split: val...
# ✅ Finished processing sample 0445.
# 🔍 Processing sample 0446 for split: train...
# ✅ Finished processing sample 0446.
# 🔍 Processing sample 0448 for split: train...
# ✅ Finished processing sample 0448.
# 🔍 Processing sample 0450 for split: train...
# ✅ Finished processing sample 0450.
# 🔍 Processing sample 0451 for split: train...
# ✅ Finished processing sample 0451.
# 🔍 Processing sample 0452 for split: train...
# ✅ Finished processing sample 0452.
# 🔍 Processing sample 0454 for split: train...
# ✅ Finished processing sample 0454.
# 🔍 Processing sample 0455 for split: train...
# ✅ Finished processing sample 0455.
# 🔍 Processing sample 0456 for split: train...
# ✅ Finished processing sample 0456.
# 🔍 Processing sample 0457 for split: train...
# ✅ Finished processing sample 0457.
# 🔍 Processing sample 0458 for split: val...
# ✅ Finished processing sample 0458.
# 🔍 Processing sample 0461 for split: train...
# ✅ Finished processing sample 0461.
# 🔍 Processing sample 0463 for split: val...
# ✅ Finished processing sample 0463.
# 🔍 Processing sample 0464 for split: test...
# ✅ Finished processing sample 0464.
# 🔍 Processing sample 0465 for split: train...
# ✅ Finished processing sample 0465.
# 🔍 Processing sample 0467 for split: val...
# ✅ Finished processing sample 0467.
# 🔍 Processing sample 0468 for split: train...
# ✅ Finished processing sample 0468.
# 🔍 Processing sample 0469 for split: val...
# ✅ Finished processing sample 0469.
# 🔍 Processing sample 0471 for split: train...
# ✅ Finished processing sample 0471.
# 🔍 Processing sample 0472 for split: val...
# ✅ Finished processing sample 0472.
# 🔍 Processing sample 0473 for split: test...
# ✅ Finished processing sample 0473.
# 🔍 Processing sample 0474 for split: train...
# ✅ Finished processing sample 0474.
# 🔍 Processing sample 0475 for split: test...
# ✅ Finished processing sample 0475.
# 🔍 Processing sample 0476 for split: train...
# ✅ Finished processing sample 0476.
# 🔍 Processing sample 0477 for split: val...
# ✅ Finished processing sample 0477.
# 🔍 Processing sample 0478 for split: test...
# ✅ Finished processing sample 0478.
# 🔍 Processing sample 0479 for split: train...
# ✅ Finished processing sample 0479.
# 🔍 Processing sample 0480 for split: train...
# ✅ Finished processing sample 0480.
# 🔍 Processing sample 0481 for split: train...
# ✅ Finished processing sample 0481.
# 🔍 Processing sample 0482 for split: test...
# ✅ Finished processing sample 0482.
# 🔍 Processing sample 0483 for split: train...
# ✅ Finished processing sample 0483.
# 🔍 Processing sample 0484 for split: train...
# ✅ Finished processing sample 0484.
# 🔍 Processing sample 0485 for split: val...
# ✅ Finished processing sample 0485.
# 🔍 Processing sample 0490 for split: train...
# ✅ Finished processing sample 0490.
# 🔍 Processing sample 0492 for split: train...
# ✅ Finished processing sample 0492.
# 🔍 Processing sample 0494 for split: train...
# ✅ Finished processing sample 0494.
# 🔍 Processing sample 0497 for split: train...
# ✅ Finished processing sample 0497.
# 🔍 Processing sample 0500 for split: test...
# ✅ Finished processing sample 0500.
# 🔍 Processing sample 0501 for split: train...
# ✅ Finished processing sample 0501.
# 🔍 Processing sample 0502 for split: test...
# ✅ Finished processing sample 0502.
# 🔍 Processing sample 0503 for split: train...
# ✅ Finished processing sample 0503.
# 🔍 Processing sample 0504 for split: val...
# ✅ Finished processing sample 0504.
# 🔍 Processing sample 0506 for split: train...
# ✅ Finished processing sample 0506.
# 🔍 Processing sample 0507 for split: train...
# ✅ Finished processing sample 0507.
# 🔍 Processing sample 0508 for split: train...
# ✅ Finished processing sample 0508.
# 🔍 Processing sample 0510 for split: train...
# ✅ Finished processing sample 0510.
# 🔍 Processing sample 0511 for split: train...
# ✅ Finished processing sample 0511.
# 🔍 Processing sample 0512 for split: train...
# ✅ Finished processing sample 0512.
# 🔍 Processing sample 0515 for split: train...
# ✅ Finished processing sample 0515.
# 🔍 Processing sample 0516 for split: train...
# ✅ Finished processing sample 0516.
# 🔍 Processing sample 0517 for split: test...
# ✅ Finished processing sample 0517.
# 🔍 Processing sample 0518 for split: train...
# ✅ Finished processing sample 0518.
# 🔍 Processing sample 0521 for split: train...
# ✅ Finished processing sample 0521.
# 🔍 Processing sample 0522 for split: train...
# ✅ Finished processing sample 0522.
# 🔍 Processing sample 0524 for split: train...
# ✅ Finished processing sample 0524.
# 🔍 Processing sample 0525 for split: train...
# ✅ Finished processing sample 0525.
# 🔍 Processing sample 0526 for split: train...
# ✅ Finished processing sample 0526.
# 🔍 Processing sample 0528 for split: val...
# ✅ Finished processing sample 0528.
# 🔍 Processing sample 0530 for split: train...
# ✅ Finished processing sample 0530.
# 🔍 Processing sample 0531 for split: train...
# ✅ Finished processing sample 0531.
# 🔍 Processing sample 0533 for split: test...
# ✅ Finished processing sample 0533.
# 🔍 Processing sample 0537 for split: train...
# ✅ Finished processing sample 0537.
# 🔍 Processing sample 0539 for split: test...
# ✅ Finished processing sample 0539.
# 🔍 Processing sample 0540 for split: train...
# ✅ Finished processing sample 0540.
# 🔍 Processing sample 0542 for split: val...
# ✅ Finished processing sample 0542.
# 🔍 Processing sample 0543 for split: test...
# ✅ Finished processing sample 0543.
# 🔍 Processing sample 0545 for split: train...
# ✅ Finished processing sample 0545.
# 🔍 Processing sample 0546 for split: train...
# ✅ Finished processing sample 0546.
# 🔍 Processing sample 0547 for split: train...
# ✅ Finished processing sample 0547.
# 🔍 Processing sample 0549 for split: test...
# ✅ Finished processing sample 0549.
# 🔍 Processing sample 0550 for split: test...
# ✅ Finished processing sample 0550.
# 🔍 Processing sample 0552 for split: train...
# ✅ Finished processing sample 0552.
# 🔍 Processing sample 0553 for split: train...
# ✅ Finished processing sample 0553.
# 🔍 Processing sample 0554 for split: train...
# ✅ Finished processing sample 0554.
# 🔍 Processing sample 0555 for split: train...
# ✅ Finished processing sample 0555.
# 🔍 Processing sample 0559 for split: train...
# ✅ Finished processing sample 0559.
# 🔍 Processing sample 0560 for split: test...
# ✅ Finished processing sample 0560.
# 🔍 Processing sample 0561 for split: train...
# ✅ Finished processing sample 0561.
# 🔍 Processing sample 0562 for split: train...
# ✅ Finished processing sample 0562.
# 🔍 Processing sample 0565 for split: val...
# ✅ Finished processing sample 0565.
# 🔍 Processing sample 0567 for split: train...
# ✅ Finished processing sample 0567.
# 🔍 Processing sample 0568 for split: train...
# ✅ Finished processing sample 0568.
# 🔍 Processing sample 0570 for split: test...
# ✅ Finished processing sample 0570.
# 🔍 Processing sample 0571 for split: train...
# ✅ Finished processing sample 0571.
# 🔍 Processing sample 0572 for split: train...
# ✅ Finished processing sample 0572.
# 🔍 Processing sample 0573 for split: train...
# ✅ Finished processing sample 0573.
# 🔍 Processing sample 0574 for split: test...
# ✅ Finished processing sample 0574.
# 🔍 Processing sample 0577 for split: val...
# ✅ Finished processing sample 0577.
# 🔍 Processing sample 0578 for split: test...
# ✅ Finished processing sample 0578.
# 🔍 Processing sample 0579 for split: train...
# ✅ Finished processing sample 0579.
# 🔍 Processing sample 0580 for split: train...
# ✅ Finished processing sample 0580.
# 🔍 Processing sample 0582 for split: train...
# ✅ Finished processing sample 0582.
# 🔍 Processing sample 0583 for split: train...
# ✅ Finished processing sample 0583.
# 🔍 Processing sample 0585 for split: train...
# ✅ Finished processing sample 0585.
# 🔍 Processing sample 0587 for split: train...
# ✅ Finished processing sample 0587.
# 🔍 Processing sample 0588 for split: train...
# ✅ Finished processing sample 0588.
# 🔍 Processing sample 0589 for split: train...
# ✅ Finished processing sample 0589.
# 🔍 Processing sample 0590 for split: train...
# ✅ Finished processing sample 0590.
# 🔍 Processing sample 0591 for split: train...
# ✅ Finished processing sample 0591.
# 🔍 Processing sample 0592 for split: val...
# ✅ Finished processing sample 0592.
# 🔍 Processing sample 0594 for split: train...
# ✅ Finished processing sample 0594.
# 🔍 Processing sample 0596 for split: train...
# ✅ Finished processing sample 0596.
# 🔍 Processing sample 0597 for split: train...
# ✅ Finished processing sample 0597.
# 🔍 Processing sample 0598 for split: train...
# ✅ Finished processing sample 0598.
# 🔍 Processing sample 0599 for split: test...
# ✅ Finished processing sample 0599.
# 🔍 Processing sample 0600 for split: val...
# ✅ Finished processing sample 0600.
# 🔍 Processing sample 0601 for split: test...
# ✅ Finished processing sample 0601.
# 🔍 Processing sample 0603 for split: train...
# ✅ Finished processing sample 0603.
# 🔍 Processing sample 0605 for split: train...
# ✅ Finished processing sample 0605.
# 🔍 Processing sample 0606 for split: train...
# ✅ Finished processing sample 0606.
# 🔍 Processing sample 0607 for split: val...
# ✅ Finished processing sample 0607.
# 🔍 Processing sample 0608 for split: val...
# ✅ Finished processing sample 0608.
# 🔍 Processing sample 0610 for split: train...
# ✅ Finished processing sample 0610.
# 🔍 Processing sample 0614 for split: val...
# ✅ Finished processing sample 0614.
# 🔍 Processing sample 0615 for split: val...
# ✅ Finished processing sample 0615.
# 🔍 Processing sample 0616 for split: train...
# ✅ Finished processing sample 0616.
# 🔍 Processing sample 0617 for split: train...
# ✅ Finished processing sample 0617.
# 🔍 Processing sample 0618 for split: train...
# ✅ Finished processing sample 0618.
# 🔍 Processing sample 0619 for split: train...
# ✅ Finished processing sample 0619.
# 🔍 Processing sample 0620 for split: test...
# ✅ Finished processing sample 0620.
# 🔍 Processing sample 0621 for split: train...
# ✅ Finished processing sample 0621.
# 🔍 Processing sample 0623 for split: train...
# ✅ Finished processing sample 0623.
# 🔍 Processing sample 0625 for split: train...
# ✅ Finished processing sample 0625.
# 🔍 Processing sample 0627 for split: val...
# ✅ Finished processing sample 0627.
# 🔍 Processing sample 0628 for split: test...
# ✅ Finished processing sample 0628.
# 🔍 Processing sample 0629 for split: train...
# ✅ Finished processing sample 0629.
# 🔍 Processing sample 0631 for split: train...
# ✅ Finished processing sample 0631.
# 🔍 Processing sample 0633 for split: train...
# ✅ Finished processing sample 0633.
# 🔍 Processing sample 0634 for split: test...
# ✅ Finished processing sample 0634.
# 🔍 Processing sample 0635 for split: train...
# ✅ Finished processing sample 0635.
# 🔍 Processing sample 0636 for split: train...
# ✅ Finished processing sample 0636.
# 🔍 Processing sample 0637 for split: val...
# ✅ Finished processing sample 0637.
# 🔍 Processing sample 0638 for split: val...
# ✅ Finished processing sample 0638.
# 🔍 Processing sample 0640 for split: train...
# ✅ Finished processing sample 0640.
# 🔍 Processing sample 0643 for split: train...
# ✅ Finished processing sample 0643.
# 🔍 Processing sample 0645 for split: test...
# ✅ Finished processing sample 0645.
# 🔍 Processing sample 0647 for split: train...
# ✅ Finished processing sample 0647.
# 🔍 Processing sample 0648 for split: val...
# ✅ Finished processing sample 0648.
# 🔍 Processing sample 0649 for split: train...
# ✅ Finished processing sample 0649.
# 🔍 Processing sample 0650 for split: val...
# ✅ Finished processing sample 0650.
# 🔍 Processing sample 0651 for split: train...
# ✅ Finished processing sample 0651.
# 🔍 Processing sample 0654 for split: train...
# ✅ Finished processing sample 0654.
# 🔍 Processing sample 0655 for split: train...
# ✅ Finished processing sample 0655.
# 🔍 Processing sample 0656 for split: train...
# ✅ Finished processing sample 0656.
# 🔍 Processing sample 0657 for split: train...
# ✅ Finished processing sample 0657.
# 🔍 Processing sample 0658 for split: train...
# ✅ Finished processing sample 0658.
# 🔍 Processing sample 0659 for split: test...
# ✅ Finished processing sample 0659.
# 🔍 Processing sample 0660 for split: train...
# ✅ Finished processing sample 0660.
# 🔍 Processing sample 0662 for split: train...
# ✅ Finished processing sample 0662.
# 🔍 Processing sample 0663 for split: test...
# ✅ Finished processing sample 0663.
# 🔍 Processing sample 0664 for split: train...
# ✅ Finished processing sample 0664.
# 🔍 Processing sample 0668 for split: test...
# ✅ Finished processing sample 0668.
# 🔍 Processing sample 0669 for split: train...
# ✅ Finished processing sample 0669.
# 🔍 Processing sample 0670 for split: train...
# ✅ Finished processing sample 0670.
# 🔍 Processing sample 0671 for split: train...
# ✅ Finished processing sample 0671.
# 🔍 Processing sample 0672 for split: train...
# ✅ Finished processing sample 0672.
# 🔍 Processing sample 0674 for split: train...
# ✅ Finished processing sample 0674.
# 🔍 Processing sample 0675 for split: test...
# ✅ Finished processing sample 0675.
# 🔍 Processing sample 0677 for split: test...
# ✅ Finished processing sample 0677.
# 🔍 Processing sample 0678 for split: train...
# ✅ Finished processing sample 0678.
# 🔍 Processing sample 0680 for split: train...
# ✅ Finished processing sample 0680.
# 🔍 Processing sample 0681 for split: train...
# ✅ Finished processing sample 0681.
# 🔍 Processing sample 0682 for split: train...
# ✅ Finished processing sample 0682.
# 🔍 Processing sample 0683 for split: train...
# ✅ Finished processing sample 0683.
# 🔍 Processing sample 0684 for split: train...
# ✅ Finished processing sample 0684.
# 🔍 Processing sample 0685 for split: test...
# ✅ Finished processing sample 0685.
# 🔍 Processing sample 0687 for split: val...
# ✅ Finished processing sample 0687.
# 🔍 Processing sample 0688 for split: val...
# ✅ Finished processing sample 0688.
# 🔍 Processing sample 0689 for split: train...
# ✅ Finished processing sample 0689.
# 🔍 Processing sample 0690 for split: val...
# ✅ Finished processing sample 0690.
# 🔍 Processing sample 0691 for split: train...
# ✅ Finished processing sample 0691.
# 🔍 Processing sample 0692 for split: test...
# ✅ Finished processing sample 0692.
# 🔍 Processing sample 0695 for split: train...
# ✅ Finished processing sample 0695.
# 🔍 Processing sample 0696 for split: test...
# ✅ Finished processing sample 0696.
# 🔍 Processing sample 0698 for split: test...
# ✅ Finished processing sample 0698.
# 🔍 Processing sample 0699 for split: test...
# ✅ Finished processing sample 0699.
# 🔍 Processing sample 0700 for split: train...
# ✅ Finished processing sample 0700.
# 🔍 Processing sample 0701 for split: train...
# ✅ Finished processing sample 0701.
# 🔍 Processing sample 0705 for split: train...
# ✅ Finished processing sample 0705.
# 🔍 Processing sample 0706 for split: val...
# ✅ Finished processing sample 0706.
# 🔍 Processing sample 0707 for split: train...
# ✅ Finished processing sample 0707.
# 🔍 Processing sample 0708 for split: train...
# ✅ Finished processing sample 0708.
# 🔍 Processing sample 0709 for split: train...
# ✅ Finished processing sample 0709.
# 🔍 Processing sample 0711 for split: train...
# ✅ Finished processing sample 0711.
# 🔍 Processing sample 0713 for split: train...
# ✅ Finished processing sample 0713.
# 🔍 Processing sample 0716 for split: val...
# ✅ Finished processing sample 0716.
# 🔍 Processing sample 0720 for split: val...
# ✅ Finished processing sample 0720.
# 🔍 Processing sample 0721 for split: val...
# ✅ Finished processing sample 0721.
# 🔍 Processing sample 0722 for split: train...
# ✅ Finished processing sample 0722.
# 🔍 Processing sample 0723 for split: test...
# ✅ Finished processing sample 0723.
# 🔍 Processing sample 0725 for split: train...
# ✅ Finished processing sample 0725.
# 🔍 Processing sample 0726 for split: train...
# ✅ Finished processing sample 0726.
# 🔍 Processing sample 0727 for split: train...
# ✅ Finished processing sample 0727.
# 🔍 Processing sample 0728 for split: train...
# ✅ Finished processing sample 0728.
# 🔍 Processing sample 0729 for split: val...
# ✅ Finished processing sample 0729.
# 🔍 Processing sample 0730 for split: train...
# ✅ Finished processing sample 0730.
# 🔍 Processing sample 0731 for split: train...
# ✅ Finished processing sample 0731.
# 🔍 Processing sample 0733 for split: train...
# ✅ Finished processing sample 0733.
# 🔍 Processing sample 0734 for split: train...
# ✅ Finished processing sample 0734.
# 🔍 Processing sample 0735 for split: train...
# ✅ Finished processing sample 0735.
# 🔍 Processing sample 0736 for split: train...
# ✅ Finished processing sample 0736.
# 🔍 Processing sample 0737 for split: train...
# ✅ Finished processing sample 0737.
# 🔍 Processing sample 0740 for split: train...
# ✅ Finished processing sample 0740.
# 🔍 Processing sample 0741 for split: train...
# ✅ Finished processing sample 0741.
# 🔍 Processing sample 0742 for split: train...
# ✅ Finished processing sample 0742.
# 🔍 Processing sample 0743 for split: train...
# ✅ Finished processing sample 0743.
# 🔍 Processing sample 0746 for split: train...
# ✅ Finished processing sample 0746.
# 🔍 Processing sample 0747 for split: val...
# ✅ Finished processing sample 0747.
# 🔍 Processing sample 0748 for split: train...
# ✅ Finished processing sample 0748.
# 🔍 Processing sample 0749 for split: test...
# ✅ Finished processing sample 0749.
# 🔍 Processing sample 0751 for split: train...
# ✅ Finished processing sample 0751.
# 🔍 Processing sample 0752 for split: train...
# ✅ Finished processing sample 0752.
# 🔍 Processing sample 0755 for split: test...
# ✅ Finished processing sample 0755.
# 🔍 Processing sample 0757 for split: train...
# ✅ Finished processing sample 0757.
# 🔍 Processing sample 0758 for split: test...
# ✅ Finished processing sample 0758.
# 🔍 Processing sample 0759 for split: train...
# ✅ Finished processing sample 0759.
# 🔍 Processing sample 0761 for split: train...
# ✅ Finished processing sample 0761.
# 🔍 Processing sample 0762 for split: train...
# ✅ Finished processing sample 0762.
# 🔍 Processing sample 0765 for split: train...
# ✅ Finished processing sample 0765.
# 🔍 Processing sample 0766 for split: train...
# ✅ Finished processing sample 0766.
# 🔍 Processing sample 0767 for split: train...
# ✅ Finished processing sample 0767.
# 🔍 Processing sample 0768 for split: train...
# ✅ Finished processing sample 0768.
# 🔍 Processing sample 0769 for split: train...
# ✅ Finished processing sample 0769.
# 🔍 Processing sample 0770 for split: train...
# ✅ Finished processing sample 0770.
# 🔍 Processing sample 0772 for split: train...
# ✅ Finished processing sample 0772.
# 🔍 Processing sample 0773 for split: train...
# ✅ Finished processing sample 0773.
# 🔍 Processing sample 0775 for split: train...
# ✅ Finished processing sample 0775.
# 🔍 Processing sample 0776 for split: train...
# ✅ Finished processing sample 0776.
# 🔍 Processing sample 0777 for split: train...
# ✅ Finished processing sample 0777.
# 🔍 Processing sample 0779 for split: test...
# ✅ Finished processing sample 0779.
# 🔍 Processing sample 0780 for split: train...
# ✅ Finished processing sample 0780.
# 🔍 Processing sample 0781 for split: train...
# ✅ Finished processing sample 0781.
# 🔍 Processing sample 0782 for split: train...
# ✅ Finished processing sample 0782.
# 🔍 Processing sample 0783 for split: val...
# ✅ Finished processing sample 0783.
# 🔍 Processing sample 0785 for split: test...
# ✅ Finished processing sample 0785.
# 🔍 Processing sample 0787 for split: train...
# ✅ Finished processing sample 0787.
# 🔍 Processing sample 0788 for split: test...
# ✅ Finished processing sample 0788.
# 🔍 Processing sample 0789 for split: train...
# ✅ Finished processing sample 0789.
# 🔍 Processing sample 0790 for split: val...
# ✅ Finished processing sample 0790.
# 🔍 Processing sample 0791 for split: test...
# ✅ Finished processing sample 0791.
# 🔍 Processing sample 0792 for split: train...
# ✅ Finished processing sample 0792.
# 🔍 Processing sample 0793 for split: train...
# ✅ Finished processing sample 0793.
# 🔍 Processing sample 0794 for split: test...
# ✅ Finished processing sample 0794.
# 🔍 Processing sample 0795 for split: train...
# ✅ Finished processing sample 0795.
# 🔍 Processing sample 0796 for split: train...
# ✅ Finished processing sample 0796.
# 🔍 Processing sample 0797 for split: train...
# ✅ Finished processing sample 0797.
# 🔍 Processing sample 0798 for split: train...
# ✅ Finished processing sample 0798.
# 🔍 Processing sample 0800 for split: test...
# ✅ Finished processing sample 0800.
# 🔍 Processing sample 0802 for split: train...
# ✅ Finished processing sample 0802.
# 🔍 Processing sample 0803 for split: train...
# ✅ Finished processing sample 0803.
# 🔍 Processing sample 0804 for split: train...
# ✅ Finished processing sample 0804.
# 🔍 Processing sample 0805 for split: train...
# ✅ Finished processing sample 0805.
# 🔍 Processing sample 0806 for split: train...
# ✅ Finished processing sample 0806.
# 🔍 Processing sample 0807 for split: train...
# ✅ Finished processing sample 0807.
# 🔍 Processing sample 0809 for split: train...
# ✅ Finished processing sample 0809.
# 🔍 Processing sample 0810 for split: train...
# ✅ Finished processing sample 0810.
# 🔍 Processing sample 0811 for split: train...
# ✅ Finished processing sample 0811.
# 🔍 Processing sample 0812 for split: train...
# ✅ Finished processing sample 0812.
# 🔍 Processing sample 0813 for split: test...
# ✅ Finished processing sample 0813.
# 🔍 Processing sample 0814 for split: train...
# ✅ Finished processing sample 0814.
# 🔍 Processing sample 0816 for split: train...
# ✅ Finished processing sample 0816.
# 🔍 Processing sample 0818 for split: train...
# ✅ Finished processing sample 0818.
# 🔍 Processing sample 0819 for split: train...
# ✅ Finished processing sample 0819.
# 🔍 Processing sample 0821 for split: train...
# ✅ Finished processing sample 0821.
# 🔍 Processing sample 0822 for split: val...
# ✅ Finished processing sample 0822.
# 🔍 Processing sample 0823 for split: val...
# ✅ Finished processing sample 0823.
# 🔍 Processing sample 0824 for split: train...
# ✅ Finished processing sample 0824.
# 🔍 Processing sample 0827 for split: test...
# ✅ Finished processing sample 0827.
# 🔍 Processing sample 0828 for split: test...
# ✅ Finished processing sample 0828.
# 🔍 Processing sample 0830 for split: train...
# ✅ Finished processing sample 0830.
# 🔍 Processing sample 0831 for split: test...
# ✅ Finished processing sample 0831.
# 🔍 Processing sample 0832 for split: train...
# ✅ Finished processing sample 0832.
# 🔍 Processing sample 0833 for split: train...
# ✅ Finished processing sample 0833.
# 🔍 Processing sample 0834 for split: train...
# ✅ Finished processing sample 0834.
# 🔍 Processing sample 0837 for split: train...
# ✅ Finished processing sample 0837.
# 🔍 Processing sample 0838 for split: train...
# ✅ Finished processing sample 0838.
# 🔍 Processing sample 0839 for split: test...
# ✅ Finished processing sample 0839.
# 🔍 Processing sample 0841 for split: train...
# ✅ Finished processing sample 0841.
# 🔍 Processing sample 0842 for split: train...
# ✅ Finished processing sample 0842.
# 🔍 Processing sample 0843 for split: train...
# ✅ Finished processing sample 0843.
# 🔍 Processing sample 0844 for split: test...
# ✅ Finished processing sample 0844.
# 🔍 Processing sample 0845 for split: val...
# ✅ Finished processing sample 0845.
# 🔍 Processing sample 0846 for split: val...
# ✅ Finished processing sample 0846.
# 🔍 Processing sample 0847 for split: train...
# ✅ Finished processing sample 0847.
# 🔍 Processing sample 0848 for split: val...
# ✅ Finished processing sample 0848.
# 🔍 Processing sample 0849 for split: train...
# ✅ Finished processing sample 0849.
# 🔍 Processing sample 0850 for split: test...
# ✅ Finished processing sample 0850.
# 🔍 Processing sample 0852 for split: test...
# ✅ Finished processing sample 0852.
# 🔍 Processing sample 0853 for split: train...
# ✅ Finished processing sample 0853.
# 🔍 Processing sample 0856 for split: train...
# ✅ Finished processing sample 0856.
# 🔍 Processing sample 0857 for split: train...
# ✅ Finished processing sample 0857.
# 🔍 Processing sample 0859 for split: train...
# ✅ Finished processing sample 0859.
# 🔍 Processing sample 0861 for split: val...
# ✅ Finished processing sample 0861.
# 🔍 Processing sample 0863 for split: val...
# ✅ Finished processing sample 0863.
# 🔍 Processing sample 0864 for split: test...
# ✅ Finished processing sample 0864.
# 🔍 Processing sample 0865 for split: train...
# ✅ Finished processing sample 0865.
# 🔍 Processing sample 0870 for split: val...
# ✅ Finished processing sample 0870.
# 🔍 Processing sample 0872 for split: train...
# ✅ Finished processing sample 0872.
# 🔍 Processing sample 0873 for split: test...
# ✅ Finished processing sample 0873.
# 🔍 Processing sample 0874 for split: train...
# ✅ Finished processing sample 0874.
# ...
# ✅ Finished processing sample 1014.
# 🔍 Processing sample 1016 for split: train...
# ✅ Finished processing sample 1016.
# 🔍 Processing sample 1018 for split: train...
# ✅ Finished processing sample 1018.
# 🔍 Processing sample 1019 for split: test...
# ✅ Finished processing sample 1019.
# 🔍 Processing sample 1020 for split: train...
# ✅ Finished processing sample 1020.
# 🔍 Processing sample 1021 for split: test...
# ✅ Finished processing sample 1021.
# 🔍 Processing sample 1022 for split: train...
# ✅ Finished processing sample 1022.
# 🔍 Processing sample 1024 for split: train...
# ✅ Finished processing sample 1024.
# 🔍 Processing sample 1025 for split: train...
# ✅ Finished processing sample 1025.
# 🔍 Processing sample 1027 for split: train...
# ✅ Finished processing sample 1027.
# 🔍 Processing sample 1031 for split: train...
# ✅ Finished processing sample 1031.
# 🔍 Processing sample 1032 for split: train...
# ✅ Finished processing sample 1032.
# 🔍 Processing sample 1033 for split: train...
# ✅ Finished processing sample 1033.
# 🔍 Processing sample 1034 for split: test...
# ✅ Finished processing sample 1034.
# 🔍 Processing sample 1037 for split: train...
# ✅ Finished processing sample 1037.
# 🔍 Processing sample 1039 for split: train...
# ✅ Finished processing sample 1039.
# 🔍 Processing sample 1040 for split: train...
# ✅ Finished processing sample 1040.
# 🔍 Processing sample 1041 for split: val...
# ✅ Finished processing sample 1041.
# 🔍 Processing sample 1042 for split: train...
# ✅ Finished processing sample 1042.
# 🔍 Processing sample 1043 for split: val...
# ✅ Finished processing sample 1043.
# 🔍 Processing sample 1044 for split: val...
# ✅ Finished processing sample 1044.
# 🔍 Processing sample 1045 for split: train...
# ✅ Finished processing sample 1045.
# 🔍 Processing sample 1046 for split: train...
# ✅ Finished processing sample 1046.
# 🔍 Processing sample 1048 for split: train...
# ✅ Finished processing sample 1048.
# 🔍 Processing sample 1051 for split: val...
# ✅ Finished processing sample 1051.
# 🔍 Processing sample 1052 for split: val...
# ✅ Finished processing sample 1052.
# 🔍 Processing sample 1053 for split: val...
# ✅ Finished processing sample 1053.
# 🔍 Processing sample 1054 for split: test...
# ✅ Finished processing sample 1054.
# 🔍 Processing sample 1055 for split: train...
# ✅ Finished processing sample 1055.
# 🔍 Processing sample 1056 for split: train...
# ✅ Finished processing sample 1056.
# 🔍 Processing sample 1058 for split: train...
# ✅ Finished processing sample 1058.
# 🔍 Processing sample 1059 for split: train...
# ✅ Finished processing sample 1059.
# 🔍 Processing sample 1061 for split: test...
# ✅ Finished processing sample 1061.
# 🔍 Processing sample 1062 for split: test...
# ✅ Finished processing sample 1062.
# 🔍 Processing sample 1063 for split: test...
# ✅ Finished processing sample 1063.
# 🔍 Processing sample 1064 for split: val...
# ✅ Finished processing sample 1064.
# 🔍 Processing sample 1066 for split: test...
# ✅ Finished processing sample 1066.
# 🔍 Processing sample 1067 for split: train...
# ✅ Finished processing sample 1067.
# 🔍 Processing sample 1068 for split: train...
# ✅ Finished processing sample 1068.
# 🔍 Processing sample 1069 for split: train...
# ✅ Finished processing sample 1069.
# 🔍 Processing sample 1070 for split: test...
# ✅ Finished processing sample 1070.
# 🔍 Processing sample 1071 for split: train...
# ✅ Finished processing sample 1071.
# 🔍 Processing sample 1072 for split: train...
# ✅ Finished processing sample 1072.
# 🔍 Processing sample 1073 for split: train...
# ✅ Finished processing sample 1073.
# 🔍 Processing sample 1076 for split: train...
# ✅ Finished processing sample 1076.
# 🔍 Processing sample 1078 for split: val...
# ✅ Finished processing sample 1078.
# 🔍 Processing sample 1082 for split: train...
# ✅ Finished processing sample 1082.
# 🔍 Processing sample 1084 for split: train...
# ✅ Finished processing sample 1084.
# 🔍 Processing sample 1085 for split: train...
# ✅ Finished processing sample 1085.
# 🔍 Processing sample 1086 for split: train...
# ✅ Finished processing sample 1086.
# 🔍 Processing sample 1087 for split: train...
# ✅ Finished processing sample 1087.
# 🔍 Processing sample 1089 for split: val...
# ✅ Finished processing sample 1089.
# 🔍 Processing sample 1091 for split: train...
# ✅ Finished processing sample 1091.
# 🔍 Processing sample 1093 for split: train...
# ✅ Finished processing sample 1093.
# 🔍 Processing sample 1094 for split: test...
# ✅ Finished processing sample 1094.
# 🔍 Processing sample 1096 for split: val...
# ✅ Finished processing sample 1096.
# 🔍 Processing sample 1097 for split: train...
# ✅ Finished processing sample 1097.
# 🔍 Processing sample 1098 for split: train...
# ✅ Finished processing sample 1098.
# 🔍 Processing sample 1099 for split: train...
# ✅ Finished processing sample 1099.
# 🔍 Processing sample 1100 for split: train...
# ✅ Finished processing sample 1100.
# 🔍 Processing sample 1101 for split: val...
# ✅ Finished processing sample 1101.
# 🔍 Processing sample 1102 for split: test...
# ✅ Finished processing sample 1102.
# 🔍 Processing sample 1103 for split: test...
# ✅ Finished processing sample 1103.
# 🔍 Processing sample 1104 for split: train...
# ✅ Finished processing sample 1104.
# 🔍 Processing sample 1106 for split: train...
# ✅ Finished processing sample 1106.
# 🔍 Processing sample 1107 for split: train...
# ✅ Finished processing sample 1107.
# 🔍 Processing sample 1109 for split: test...
# ✅ Finished processing sample 1109.
# 🔍 Processing sample 1110 for split: train...
# ✅ Finished processing sample 1110.
# 🔍 Processing sample 1111 for split: train...
# ✅ Finished processing sample 1111.
# 🔍 Processing sample 1112 for split: train...
# ✅ Finished processing sample 1112.
# 🔍 Processing sample 1113 for split: val...
# ✅ Finished processing sample 1113.
# 🔍 Processing sample 1114 for split: train...
# ✅ Finished processing sample 1114.
# 🔍 Processing sample 1116 for split: train...
# ✅ Finished processing sample 1116.
# 🔍 Processing sample 1117 for split: train...
# ✅ Finished processing sample 1117.
# 🔍 Processing sample 1118 for split: train...
# ✅ Finished processing sample 1118.
# 🔍 Processing sample 1119 for split: train...
# ✅ Finished processing sample 1119.
# 🔍 Processing sample 1120 for split: train...
# ✅ Finished processing sample 1120.
# 🔍 Processing sample 1121 for split: train...
# ✅ Finished processing sample 1121.
# 🔍 Processing sample 1123 for split: test...
# ✅ Finished processing sample 1123.
# 🔍 Processing sample 1124 for split: train...
# ✅ Finished processing sample 1124.
# 🔍 Processing sample 1125 for split: train...
# ✅ Finished processing sample 1125.
# 🔍 Processing sample 1126 for split: train...
# ✅ Finished processing sample 1126.
# 🔍 Processing sample 1127 for split: train...
# ✅ Finished processing sample 1127.
# 🔍 Processing sample 1132 for split: train...
# ✅ Finished processing sample 1132.
# 🔍 Processing sample 1133 for split: train...
# ✅ Finished processing sample 1133.
# 🔍 Processing sample 1134 for split: train...
# ✅ Finished processing sample 1134.
# 🔍 Processing sample 1135 for split: test...
# ✅ Finished processing sample 1135.
# 🔍 Processing sample 1136 for split: train...
# ✅ Finished processing sample 1136.
# 🔍 Processing sample 1138 for split: train...
# ✅ Finished processing sample 1138.
# 🔍 Processing sample 1139 for split: val...
# ✅ Finished processing sample 1139.
# 🔍 Processing sample 1140 for split: train...
# ✅ Finished processing sample 1140.
# 🔍 Processing sample 1141 for split: train...
# ✅ Finished processing sample 1141.
# 🔍 Processing sample 1142 for split: train...
# ✅ Finished processing sample 1142.
# 🔍 Processing sample 1143 for split: val...
# ✅ Finished processing sample 1143.
# 🔍 Processing sample 1145 for split: train...
# ✅ Finished processing sample 1145.
# 🔍 Processing sample 1146 for split: train...
# ✅ Finished processing sample 1146.
# 🔍 Processing sample 1147 for split: train...
# ✅ Finished processing sample 1147.
# 🔍 Processing sample 1148 for split: test...
# ✅ Finished processing sample 1148.
# 🔍 Processing sample 1149 for split: train...
# ✅ Finished processing sample 1149.
# 🔍 Processing sample 1150 for split: train...
# ✅ Finished processing sample 1150.
# 🔍 Processing sample 1151 for split: train...
# ✅ Finished processing sample 1151.
# 🔍 Processing sample 1152 for split: val...
# ✅ Finished processing sample 1152.
# 🔍 Processing sample 1153 for split: test...
# ✅ Finished processing sample 1153.
# 🔍 Processing sample 1154 for split: train...
# ✅ Finished processing sample 1154.
# 🔍 Processing sample 1155 for split: train...
# ✅ Finished processing sample 1155.
# 🔍 Processing sample 1157 for split: train...
# ✅ Finished processing sample 1157.
# 🔍 Processing sample 1160 for split: test...
# ✅ Finished processing sample 1160.
# 🔍 Processing sample 1161 for split: train...
# ✅ Finished processing sample 1161.
# 🔍 Processing sample 1162 for split: train...
# ✅ Finished processing sample 1162.
# 🔍 Processing sample 1163 for split: test...
# ✅ Finished processing sample 1163.
# 🔍 Processing sample 1164 for split: val...
# ✅ Finished processing sample 1164.
# 🔍 Processing sample 1166 for split: train...
# ✅ Finished processing sample 1166.
# 🔍 Processing sample 1167 for split: train...
# ✅ Finished processing sample 1167.
# 🔍 Processing sample 1168 for split: train...
# ✅ Finished processing sample 1168.
# 🔍 Processing sample 1169 for split: test...
# ✅ Finished processing sample 1169.
# 🔍 Processing sample 1170 for split: train...
# ✅ Finished processing sample 1170.
# 🔍 Processing sample 1171 for split: train...
# ✅ Finished processing sample 1171.
# 🔍 Processing sample 1173 for split: test...
# ✅ Finished processing sample 1173.
# 🔍 Processing sample 1174 for split: train...
# ✅ Finished processing sample 1174.
# 🔍 Processing sample 1177 for split: val...
# ✅ Finished processing sample 1177.
# 🔍 Processing sample 1178 for split: train...
# ✅ Finished processing sample 1178.
# 🔍 Processing sample 1180 for split: train...
# ✅ Finished processing sample 1180.
# 🔍 Processing sample 1181 for split: val...
# ✅ Finished processing sample 1181.
# 🔍 Processing sample 1182 for split: train...
# ✅ Finished processing sample 1182.
# 🔍 Processing sample 1183 for split: train...
# ✅ Finished processing sample 1183.
# 🔍 Processing sample 1186 for split: train...
# ✅ Finished processing sample 1186.
# 🔍 Processing sample 1188 for split: train...
# ✅ Finished processing sample 1188.
# 🔍 Processing sample 1190 for split: train...
# ✅ Finished processing sample 1190.
# 🔍 Processing sample 1192 for split: train...
# ✅ Finished processing sample 1192.
# 🔍 Processing sample 1193 for split: train...
# ✅ Finished processing sample 1193.
# 🔍 Processing sample 1194 for split: train...
# ✅ Finished processing sample 1194.
# 🔍 Processing sample 1197 for split: train...
# ✅ Finished processing sample 1197.
# 🔍 Processing sample 1200 for split: train...
# ✅ Finished processing sample 1200.
# 🔍 Processing sample 1201 for split: train...
# ✅ Finished processing sample 1201.
# 🔍 Processing sample 1203 for split: test...
# ✅ Finished processing sample 1203.
# 🔍 Processing sample 1204 for split: val...
# ✅ Finished processing sample 1204.
# 🔍 Processing sample 1208 for split: train...
# ✅ Finished processing sample 1208.
# 🔍 Processing sample 1210 for split: val...
# ✅ Finished processing sample 1210.
# 🔍 Processing sample 1211 for split: train...
# ✅ Finished processing sample 1211.
# 🔍 Processing sample 1212 for split: train...
# ✅ Finished processing sample 1212.
# 🔍 Processing sample 1213 for split: test...
# ✅ Finished processing sample 1213.
# 🔍 Processing sample 1217 for split: train...
# ✅ Finished processing sample 1217.
# 🔍 Processing sample 1218 for split: train...
# ✅ Finished processing sample 1218.
# 🔍 Processing sample 1220 for split: train...
# ✅ Finished processing sample 1220.
# 🔍 Processing sample 1221 for split: train...
# ✅ Finished processing sample 1221.
# 🔍 Processing sample 1222 for split: train...
# ✅ Finished processing sample 1222.
# 🔍 Processing sample 1223 for split: train...
# ✅ Finished processing sample 1223.
# 🔍 Processing sample 1225 for split: train...
# ✅ Finished processing sample 1225.
# 🔍 Processing sample 1226 for split: val...
# ✅ Finished processing sample 1226.
# 🔍 Processing sample 1227 for split: train...
# ✅ Finished processing sample 1227.
# 🔍 Processing sample 1228 for split: train...
# ✅ Finished processing sample 1228.
# 🔍 Processing sample 1229 for split: train...
# ✅ Finished processing sample 1229.
# 🔍 Processing sample 1232 for split: train...
# ✅ Finished processing sample 1232.
# 🔍 Processing sample 1234 for split: train...
# ✅ Finished processing sample 1234.
# 🔍 Processing sample 1235 for split: train...
# ✅ Finished processing sample 1235.
# 🔍 Processing sample 1237 for split: test...
# ✅ Finished processing sample 1237.
# 🔍 Processing sample 1239 for split: val...
# ✅ Finished processing sample 1239.
# 🔍 Processing sample 1240 for split: train...
# ✅ Finished processing sample 1240.
# 🔍 Processing sample 1242 for split: train...
# ✅ Finished processing sample 1242.
# 🔍 Processing sample 1244 for split: val...
# ✅ Finished processing sample 1244.
# 🔍 Processing sample 1245 for split: train...
# ✅ Finished processing sample 1245.
# 🔍 Processing sample 1246 for split: train...
# ✅ Finished processing sample 1246.
# 🔍 Processing sample 1247 for split: val...
# ✅ Finished processing sample 1247.
# 🔍 Processing sample 1248 for split: test...
# ✅ Finished processing sample 1248.
# 🔍 Processing sample 1249 for split: train...
# ✅ Finished processing sample 1249.
# 🔍 Processing sample 1250 for split: train...
# ✅ Finished processing sample 1250.
# 🔍 Processing sample 1253 for split: train...
# ✅ Finished processing sample 1253.
# 🔍 Processing sample 1256 for split: test...
# ✅ Finished processing sample 1256.
# 🔍 Processing sample 1257 for split: train...
# ✅ Finished processing sample 1257.
# 🔍 Processing sample 1258 for split: train...
# ✅ Finished processing sample 1258.
# 🔍 Processing sample 1260 for split: train...
# ✅ Finished processing sample 1260.
# 🔍 Processing sample 1261 for split: train...
# ✅ Finished processing sample 1261.
# 🔍 Processing sample 1263 for split: train...
# ✅ Finished processing sample 1263.
# 🔍 Processing sample 1265 for split: train...
# ✅ Finished processing sample 1265.
# 🔍 Processing sample 1266 for split: test...
# ✅ Finished processing sample 1266.
# 🔍 Processing sample 1267 for split: train...
# ✅ Finished processing sample 1267.
# 🔍 Processing sample 1268 for split: train...
# ✅ Finished processing sample 1268.
# 🔍 Processing sample 1269 for split: train...
# ✅ Finished processing sample 1269.
# 🔍 Processing sample 1270 for split: test...
# ✅ Finished processing sample 1270.
# 🔍 Processing sample 1271 for split: val...
# ✅ Finished processing sample 1271.
# 🔍 Processing sample 1272 for split: train...
# ✅ Finished processing sample 1272.
# 🔍 Processing sample 1273 for split: train...
# ✅ Finished processing sample 1273.
# 🔍 Processing sample 1274 for split: train...
# ✅ Finished processing sample 1274.
# 🔍 Processing sample 1276 for split: train...
# ✅ Finished processing sample 1276.
# 🔍 Processing sample 1277 for split: test...
# ✅ Finished processing sample 1277.
# 🔍 Processing sample 1279 for split: val...
# ✅ Finished processing sample 1279.
# 🔍 Processing sample 1280 for split: train...
# ✅ Finished processing sample 1280.
# 🔍 Processing sample 1281 for split: train...
# ✅ Finished processing sample 1281.
# 🔍 Processing sample 1282 for split: val...
# ✅ Finished processing sample 1282.
# 🔍 Processing sample 1283 for split: train...
# ✅ Finished processing sample 1283.
# 🔍 Processing sample 1285 for split: train...
# ✅ Finished processing sample 1285.
# 🔍 Processing sample 1286 for split: train...
# ✅ Finished processing sample 1286.
# 🔍 Processing sample 1287 for split: train...
# ✅ Finished processing sample 1287.
# 🔍 Processing sample 1289 for split: test...
# ✅ Finished processing sample 1289.
# 🔍 Processing sample 1290 for split: train...
# ✅ Finished processing sample 1290.
# 🔍 Processing sample 1292 for split: test...
# ✅ Finished processing sample 1292.
# 🔍 Processing sample 1296 for split: train...
# ✅ Finished processing sample 1296.
# 🔍 Processing sample 1297 for split: train...
# ✅ Finished processing sample 1297.
# 🔍 Processing sample 1300 for split: train...
# ✅ Finished processing sample 1300.
# 🎯 Dataset processing complete!
# 📁 Train data saved in: ./DatasetPro/train_features.csv
# 📁 Validation data saved in: ./DatasetPro/val_features.csv
# 📁 Test data saved in: ./DatasetPro/test_features.csv
